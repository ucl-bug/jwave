# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Full wave inversion

# %% [markdown]
# ## Setup the problem

# %%
from jax import numpy as jnp
import numpy as np

# %%
# Defining geometry
from jwave.geometry import kGrid, TimeAxis, Medium, Sources, Sensors, _points_on_circle, _circ_mask
from jwave.physics import simulate_wave_propagation

N = (128, 128)
dx = (.5, .5)

cfl = 0.25

grid = kGrid.make_grid(N, dx)

# %%
# Physical properties
sound_speed = jnp.ones(N) 
circle_1 = _circ_mask(N, 8, (50,50))
circle_2 = _circ_mask(N, 10, (78,64))
circle_3 = _circ_mask(N, 20, (65,65))
circle_4 = _circ_mask(N, 22, (65,65))
sound_speed = sound_speed + 0.1*circle_1 + 0.13*circle_2 + 0.7*(circle_4-circle_3)

# Physical properties
medium = Medium(
    sound_speed=sound_speed,
    density=jnp.ones(N),
    attenuation=0.0,
    pml_size=20
)

time_array = TimeAxis.from_kgrid(grid, medium, cfl=cfl, t_end=80.)
output_time_array = TimeAxis(dt = time_array.dt,t_end = time_array.t_end)

# %%
# define a source point
from jwave.signal_processing import gaussian_window, apply_ramp

num_sources = 32
source_freq = .5
source_mag = 5/time_array.dt


t = jnp.arange(0, time_array.t_end, time_array.dt)
s1 = source_mag * jnp.sin(2 * jnp.pi * source_freq * t)
signal = gaussian_window(apply_ramp(s1, time_array.dt, source_freq), t, 5, 2)

mask = _circ_mask(N, 38, (64,64))
x, y = _points_on_circle(num_sources,40,(64,64))
source_positions = (jnp.array(x), jnp.array(y))

# %%
# Define sensors
sensors_positions = (x, y)
sensors = Sensors(positions=sensors_positions)

# %% [markdown]
# Let's look at the problem setup

# %%
# Show simulation setup
from matplotlib import pyplot as plt

fig, ax = plt.subplots(1,2,figsize=(15,4), gridspec_kw={'width_ratios': [1, 2]})

ax[0].imshow(medium.sound_speed, cmap="gray")
ax[0].scatter(source_positions[1],source_positions[0], c='r', marker='x', label="sources")
ax[0].scatter(sensors_positions[1],sensors_positions[0], c='g', marker='.', label="sensors")
ax[0].legend()
ax[0].set_title("Speed of sound")
ax[0].axis("off")

ax[1].plot(signal, label="Source 1", c='k')
ax[1].set_title("Source signals")
ax[1].get_yaxis().set_visible(False)

# %% [markdown]
# ## Run the simulation

# %%
from functools import partial
import jax


@jax.jit
def single_source_simulation(source_freq,speed_of_sound,source_num):
    source_mag = 5/time_array.dt
    t = jnp.arange(0, time_array.t_end, time_array.dt)
    s1 = source_mag * jnp.sin(2 * jnp.pi * source_freq * t)
    signal = gaussian_window(apply_ramp(s1, time_array.dt, source_freq), t, 5, 2)

    # Setting source
    x = jax.lax.dynamic_slice(source_positions[0], (source_num,), (1,))
    y = jax.lax.dynamic_slice(source_positions[1], (source_num,), (1,))
    src_signal = jnp.stack([signal])
    sources = Sources((x,y), src_signal)
    medium = Medium(
        sound_speed=speed_of_sound,
        density=1.0,
        attenuation=0.0,
        pml_size=20
    )
    
    # Run simulations
    fields = simulate_wave_propagation(grid, medium, time_array, sources, sensors,
                                  output_t_axis = output_time_array, backprop=False)
    
    # Return pressure
    p = jnp.sum(fields[1],1)*(medium.sound_speed[sources.positions]**2)
    return p

batch_simulations = jax.jit(jax.vmap(single_source_simulation, (None,None,0), 0))

# %%
from functools import partial
from luprox import linear_uncertainty
# Single source simulation with uncertainty propagation
def up_single_source(center, center_cov, speed_of_sound,source_num):
    f = partial(single_source_simulation, speed_of_sound=speed_of_sound, source_num=source_num)
    return linear_uncertainty(f)(center, center_cov)

# %%
f_cov = jnp.array([[0.0001]])
center = jnp.array([.5])
p_data, p_variance = up_single_source(center, f_cov, medium.sound_speed, 16)
# Out:
# /home/astanziola/anaconda3/envs/jwave/lib/python3.7/site-packages/jax/_src/numpy/lax_numpy.py:2968: ComplexWarning: Casting complex values to real discards the imaginary part
#   out = lax._convert_element_type(out, dtype, weak_type=weak_type)

# %%
y = p_data[550:,0]
sigma_3 = jnp.sqrt(p_variance[550:,0])*3

# %%
t = jnp.arange(0,len(y)*time_array.dt, time_array.dt)
print(len(t))
plt.figure(figsize=(15,5))
plt.fill_between(
    t, 
    y-sigma_3, 
    y+sigma_3, 
    color="red", 
    alpha=0.5, 
    label="2$\sigma$ interval"
)
plt.xlim([t[0], t[-1]])
plt.plot(t, y, color="black")
plt.title("Estimated uncertainty and samples")
plt.legend()
plt.show()
# Out:
# 623

# %%
from functools import partial
from luprox import monte_carlo
# Single source simulation with uncertainty propagation
def mc_single_source(key, center, center_cov, speed_of_sound, source_num):
    f = partial(single_source_simulation, speed_of_sound=speed_of_sound, source_num=source_num)
    single_trace_f = lambda x: f(x)[:,0]
    return monte_carlo(single_trace_f, trials=100)(center, center_cov, key)

# %%
key = jax.random.PRNGKey(40)
f_cov = jnp.array([[0.0001]])
center = jnp.array([.5])
samples = mc_single_source(key, center, f_cov, medium.sound_speed, 16)
print(samples.shape)
# Out:
# /home/astanziola/anaconda3/envs/jwave/lib/python3.7/site-packages/jax/_src/numpy/lax_numpy.py:2968: ComplexWarning: Casting complex values to real discards the imaginary part
#   out = lax._convert_element_type(out, dtype, weak_type=weak_type)
# (100, 1173)

# %%
t = jnp.arange(0,len(y)*time_array.dt, time_array.dt)

plt.figure(figsize=(15,5))
plt.fill_between(
    t, 
    y-sigma_3, 
    y+sigma_3, 
    color="orange", 
    alpha=0.2, 
    label="2$\sigma$ interval"
)
plt.xlim([t[0], t[-1]])
plt.plot(t, samples[:,550:].T, color="black", alpha=0.03)
plt.plot(t, y-sigma_3,color="red",linestyle="-.")
plt.plot(t, y+sigma_3,color="red",linestyle="-.")
plt.title("Estimated uncertainty and samples")
plt.legend()
plt.show()

# %%
y = p_data[300:500]
sigma_3 = jnp.sqrt(p_variance[300:500])*3

# %%
t = jnp.arange(0,len(y)*time_array.dt, time_array.dt)
print(len(t))
plt.figure(figsize=(15,5))
plt.fill_between(
    t, 
    y-sigma_3, 
    y+sigma_3, 
    color="red", 
    alpha=0.5, 
    label="2$\sigma$ interval"
)
plt.xlim([t[0], t[-1]])
plt.plot(t, y, color="black", alpha=0.2)
plt.title("Estimated uncertainty and samples")
plt.legend()
plt.show()
# Out:
# 200
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-5e9398d19a81> in <module>
#       8     color="red",
#       9     alpha=0.5,
# ---> 10     label="2$\sigma$ interval"
#      11 )
#      12 plt.xlim([t[0], t[-1]])
#
# ~/anaconda3/envs/jwave/lib/python3.7/site-packages/matplotlib/pyplot.py in fill_between(x, y1, y2, where, interpolate, step, data, **kwargs)
#    2775     return gca().fill_between(
#    2776         x, y1, y2=y2, where=where, interpolate=interpolate, step=step,
# -> 2777         **({"data": data} if data is not None else {}), **kwargs)
#    2778
#    2779
#
# ~/anaconda3/envs/jwave/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1350     def inner(ax, *args, data=None, **kwargs):
#    1351         if data is None:
# -> 1352             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1353
#    1354         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/anaconda3/envs/jwave/lib/python3.7/site-packages/matplotlib/axes/_axes.py in fill_between(self, x, y1, y2, where, interpolate, step, **kwargs)
#    5366         return self._fill_between_x_or_y(
#    5367             "x", x, y1, y2,
# -> 5368             where=where, interpolate=interpolate, step=step, **kwargs)
#    5369
#    5370     if _fill_between_x_or_y.__doc__:
#
# ~/anaconda3/envs/jwave/lib/python3.7/site-packages/matplotlib/axes/_axes.py in _fill_between_x_or_y(self, ind_dir, ind, dep1, dep2, where, interpolate, step, **kwargs)
#    5277                 (ind_dir, ind), (f"{dep_dir}1", dep1), (f"{dep_dir}2", dep2)]:
#    5278             if array.ndim > 1:
# -> 5279                 raise ValueError(f"{name!r} is not 1-dimensional")
#    5280
#    5281         if where is None:
#
# ValueError: 'y1' is not 1-dimensional

# %%
p_data = batch_simulations(signal, medium.sound_speed, jnp.arange(num_sources))
print(p_data.shape)
# Out:
# (32, 770, 32)

# %%
# Run simulation
p = single_source_simulation(medium.sound_speed, 1)

# %%
# %%timeit
single_source_simulation(medium.sound_speed, 1)
# Out:
# 111 ms ± 1.25 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %%timeit
batch_simulations(medium.sound_speed, jnp.arange(num_sources))
# Out:
# 1.07 s ± 199 µs per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# ## Define the optimization problem

# %%
from jax import random, nn, value_and_grad, jit, jvp, grad, vmap, jacfwd
from jax import lax
from jax.experimental import stax
from jwave.signal_processing import smooth, apply_ramp

key = random.PRNGKey(42)

# %%
def get_sound_speed(params):
    return jnp.ones(N) + nn.sigmoid(params)*mask

# %%
def init_sos():
    old_sos_params = jnp.log((medium.sound_speed - 0.99)/(1-medium.sound_speed + 0.99))
    for _ in range(100):
        old_sos_params= smooth(old_sos_params)
    return old_sos_params
params = init_sos()
sos = get_sound_speed(params)

# %%
def plot_sos(sos, ax = None):
    if ax is None:
        fig, ax = plt.subplots(1,1,figsize=(8,6))

        ax.imshow(sos, cmap="inferno", vmax=1.3)
        ax.scatter(source_positions[1],source_positions[0], c='r', marker='x', label="sources")
        ax.scatter(sensors_positions[1],sensors_positions[0], c='g', marker='o', label="sensors")
        ax.legend()

plot_sos(sos)
plt.title("Initial speed of sound distribution")
plt.show()

# %%
def loss_func(p, source_num):
    '''
    Maximizes energy at central sensor, minimize energy external ones'''
    diff = p_data[source_num] - p
    return 1e3*jnp.mean(jnp.abs(diff)**2)
                
def get_sensor_signals(params, source_num):
    p = single_source_simulation(get_sound_speed(params), source_num)
    return p

def loss_with_grad(params, source_num):
    lossval, gradient = value_and_grad(
        lambda x: loss_func(get_sensor_signals(x, source_num),source_num)
    )(params)
    return lossval, gradient

# %% [markdown]
# ## Optimize

# %%
from tqdm import tqdm
from jax.experimental import optimizers

# %%
loss, gradient = loss_with_grad(params, 24)
print(loss)
# Out:
# 0.48412636

# %%
plt.figure(figsize=(8,6))
plt.imshow(gradient, cmap="seismic", vmin=-.002, vmax=.002)
plt.title("Gradient")
# Out:
# Text(0.5, 1.0, 'Gradient')

# %%
losshistory = []
reconstructions = []

init_fun, update_fun, get_params = optimizers.adam(.1, 0.9, 0.9)
opt_state = init_fun(params)

@jit
def update(opt_state, key, k):
    v = get_params(opt_state)
    src_num = random.choice(key, num_sources)
    lossval, gradient = loss_with_grad(v, src_num)
    return lossval, update_fun(k, gradient, opt_state)

pbar = tqdm(range(1000))
_, key = random.split(key)
for k in pbar:
    _, key = random.split(key)
    lossval, opt_state = update(opt_state, key, k)
    
    # For logging
    new_params = get_params(opt_state)
    reconstructions.append(get_sound_speed(new_params))
    losshistory.append(lossval)
    
    pbar.set_description("Loss: {}".format(lossval))
# Out:
# Loss: 0.0030334144830703735: 100%|██████████| 1000/1000 [13:29<00:00,  1.24it/s]

# %%
new_params = get_params(opt_state)

# %%
sos_original = get_sound_speed(params)
true_sos = sound_speed

fig, axes = plt.subplots(3,4, figsize=(15,10))

k = 0
recs = [0, 1, 3, 10, 20, 30, 50, 999]
for row in range(3):
    for col in range(4):
        if k ==0:
            axes[row,col].imshow(true_sos, cmap="inferno", vmax=1.2)
            axes[row,col].scatter(sensors_positions[1],sensors_positions[0], c='g', marker='x', label="sensors")
            axes[row,col].set_title("True speed of sound")
            axes[row,col].set_axis_off()
        elif k ==1:
            axes[row,col].imshow(sos_original, cmap="inferno", vmax=1.2)
            axes[row,col].set_axis_off()
            axes[row,col].set_title("Initial guess")
        elif k ==2:
            axes[row,col].plot(losshistory)
            axes[row,col].set_title("Loss")
            axes[row,col].set_yscale("log")
        elif k == 3:
            axes[row,col].set_axis_off()
        else:
            axes[row,col].imshow(reconstructions[recs[k-4]], cmap="inferno", vmax=1.2)
            axes[row,col].set_axis_off()
            axes[row,col].set_title("Step {}".format(recs[k-4]+1))
        k += 1
