# %%
from scipy.io import loadmat
from matplotlib import pyplot as plt
import numpy as np

# %%
filename = "helmholtz_autodiff_(48,_48)_(0.001,_0.001)_heterogeneous_heterogeneous_heterogeneous_1000000.0.mat"
a = loadmat("regression_data/" + filename)

# %%
a.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'sos_gradient', 'density_gradient', 'attenuation_gradient', 'omega_gradient', 'src_gradient', 'field'])

# %%
field = a["density_gradient"]

# %%
plt.imshow(np.real(field), cmap="RdBu")
plt.colorbar()
